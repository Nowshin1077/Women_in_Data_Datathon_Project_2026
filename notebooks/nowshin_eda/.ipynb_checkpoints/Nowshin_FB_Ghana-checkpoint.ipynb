# %% [markdown]
# # 1. Data Cleaning and Feature Extraction

# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
# 1. Output directory for exported chart assets
FIGURES_DIR = "figures_FB"
os.makedirs(FIGURES_DIR, exist_ok=True)

# %%
# 2. Load Raw FB Dataset
df_raw = pd.read_csv(r"D:\Plateful_of_Data_Datathon26\Women_in_Data_Datathon_Project_2026\dataset\FAOSTAT_FB_Ghana.csv")

df_raw.head()
# Out:
#   Domain Code                 Domain  Area Code (M49)   Area  Element Code  \
# 0         FBS  Food Balances (2010-)              288  Ghana           511
# 1         FBS  Food Balances (2010-)              288  Ghana           511
# 2         FBS  Food Balances (2010-)              288  Ghana           511
# 3         FBS  Food Balances (2010-)              288  Ghana           511
# 4         FBS  Food Balances (2010-)              288  Ghana           511
#
#                          Element Item Code (FBS)        Item  Year Code  Year  \
# 0  Total Population - Both sexes           S2501  Population       2010  2010
# 1  Total Population - Both sexes           S2501  Population       2011  2011
# 2  Total Population - Both sexes           S2501  Population       2012  2012
# 3  Total Population - Both sexes           S2501  Population       2013  2013
# 4  Total Population - Both sexes           S2501  Population       2014  2014
#
# ...

# %% [markdown]
# # 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# # 3. Data Visualization
